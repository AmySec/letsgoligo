# %%
import numpy as np
import matplotlib as plt
from pylab import *
# %matplotlib inline

# %%
## Reads the data file but only from the columns in @usecols
data = loadtxt('output.dat', usecols = (1, 2, 3, 10, 11, 13, 14))
#print data

# %%
## assigns each column in data to the specific value the data represents
bodNum = data[:,0][::101]  # colon equals everything
mass = data[:,1]
time = data[:,2]
xpos = data[:,3]
ypos = data[:,4]
velx = data[:,5]
vely = data[:,6]

# %% [markdown]
# Graph should refer to time, in order to reference when

# %%
## Calculates the initial velocity of the blackhole
def totalVel(vel):
    print vel

# %%
obj0 = bodNum == 0
obj1 = bodNum == 1

# %%
##
# Experimenting
##
fig = plt.figure()

index = 0


for obj in bodNum:
    if obj == 0:
        colorDot = 'red'
    if obj == 1:
        colorDot = 'blue'
    if obj == bodNum[(index - 1)]:
        colorDot = 'purple'
    plt.plot(xpos[index], ypos[index],'.',c = colorDot)
    
    index += 1 

plt.plot([xpos[0],xpos[2]],[ypos[0],ypos[2]],c = "pink")

# %%
##
# Final
##
fig = plt.figure()
index = 0


for obj in bodNum:
    if obj == 0:
        colorDot = 'red'
    if obj == 1:
        colorDot = 'blue'
    if obj == bodNum[(index - 1)]:
        colorDot = 'purple'
    plt.plot(xpos[index], ypos[index],'.',c = colorDot, )

    index += 1
plt.title("Sample Position of  Black Holes")
plt.xlabel("X-Position")
plt.ylabel("Y-Position")
plt.scatter(xpos[0],ypos[0], c = "black")
plt.legend()
